# %% [markdown]
# # TeaStore
#
# Here we only study the behaviour of the login requests in the teastore application and look at how it scales on a single machine.

# %%
library(ggplot2)
library(dplyr)
library(tidyr)
library(tikzDevice)
library(gridExtra)
library(ggpubr)
library("ggsci")

# %%
setwd("/home/clem/Code/github.com/klementc/calvin-microbenchmarks/comparison/")

dataSG <- as_tibble(read.csv("./results_reprod/teastore/teastore_sg.csv"))
head(dataSG)
dataTS <- as_tibble(read.csv("./results_reprod/teastore/resTeaStoreCombined.csv"))
dataTS <- dataTS[dataTS$Load.Intensity != 0,] 
head(dataTS)
# Out:
#   nbC load reqpersec
# 1 4     1    1
# 2 4    21   21
# 3 4    41   41
# 4 4    61   61
# 5 4    81   81
# 6 4   101  101
#   Sample nbC Target.Time Load.Intensity Successful.Transactions
# 1 1      4   0.5          8              8
# 2 1      4   1.5         16             16
# 3 1      4   2.5         25             25
# 4 1      4   3.5         33             33
# 5 1      4   4.5         41             41
# 6 1      4   5.5         50             49
#   Failed.Transactions Dropped.Transactions Avg.Response.Time
# 1 0                   0                    0.081
# 2 0                   0                    0.030
# 3 0                   0                    0.020
# 4 0                   0                    0.012
# 5 0                   0                    0.012
# 6 0                   0                    0.011
#   Final.Batch.Dispatch.Time X18.05.2021.12.07.17444
# 1 0.430                     NA
# 2 1.482                     NA
# 3 2.494                     NA
# 4 3.503                     NA
# 5 4.474                     NA
# 6 5.489                     NA

# %%
gc <- ggplot() +
  geom_point(data = dataTS, aes(x=Load.Intensity, y=Successful.Transactions,group=nbC,colour=factor(nbC)),alpha=.5)+
  geom_line(data = dataSG, aes(x=load, y=reqpersec, group=nbC),size=2)
gc
# Out:
# plot without title

# %%
options(repr.plot.width=10, repr.plot.height=8)


dataTS$nbCf = factor(dataTS$nbC, levels=c('4 Cores','8 Cores','16 Cores'))
dataSG$nbCf = factor(dataSG$nbC, levels=c('4 Cores','8 Cores','16 Cores'))

#dataSG <- dataSG %>%
#  mutate(nbC = recode(nbC, "4" = "4 Cores", "8" = "8 Cores", "16" = "16 Cores"))

gc <- ggplot() +
  #  geom_line(data = datasg, aes(x=load, y=reqPerSec, group=nbn, colour=factor(nbn), linetype="SG"),size=1.5)+
  geom_point(data = dataTS, aes(x=Load.Intensity, y=Successful.Transactions,group=nbC,colour=factor(nbC)),alpha=.5)+
  geom_line(data = dataSG, aes(x=load, y=reqpersec, group=nbC),size=2)+
  facet_wrap("nbC",ncol=1,scales="free")+ scale_fill_simpsons()+
  theme(text = element_text(size = 25))+theme(legend.position = "none")+
  labs(y="Executed Workload (RPS)", x="Input Load (RPS)")
gc
ggsave("plotTeaStore.pdf", plot=gc, width=10, height=8)
# Out:
# plot without title
